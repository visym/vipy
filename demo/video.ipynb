# %%
import vipy.video
import vipy.object
from vipy.geometry import BoundingBox

# %%
mp4file = '/Users/jba3139/Desktop/Video.mp4'
vid = vipy.video.Scene(filename=mp4file, tracks=[vipy.object.Track('RandomBox1', frames=[0,200], boxes=[BoundingBox(xmin=0,ymin=0,width=200,height=400), BoundingBox(xmin=100,ymin=200,width=400,height=100)]),
                                                 vipy.object.Track('RandomBox2', frames=[0,200], boxes=[BoundingBox(xmin=100,ymin=200,width=300,height=400), BoundingBox(xmin=400,ymin=300,width=100,height=400)])])
print(vid)
# Out:
# <vipy.video.scene: filename="/Users/jba3139/Desktop/Video.mp4", tracks=2>

# %%
vid.load()
# Out:
# <vipy.video.scene: height=1920, width=1080, frames=321, filename="/Users/jba3139/Desktop/Video.mp4", tracks=2>

# %%
vid.numpy().shape
# Out:
# (321, 1920, 1080, 3)

# %%
vid[100].rescale(0.25).show()
# Out:
# <vipy.image.scene: height=480, width=270, color='rgb', objects=2>

# %%
vid = vid.flush().rot90ccw().rescale(0.25).load()

# %%
vid[100].show()
# Out:
# <vipy.image.scene: height=270, width=480, color='rgb', objects=2>

# %%
vid[100].objects()
# Out:
# [<vipy.object.detection: category="RandomBox1", bbox=(xmin=25.0,ymin=182.5,xmax=87.5,ymax=257.5)>,
#  <vipy.object.detection: category="RandomBox2", bbox=(xmin=62.5,ymin=157.5,xmax=162.5,ymax=207.5)>]

# %%
vid[130].show()
# Out:
# <vipy.image.scene: height=270, width=480, color='rgb', objects=2>

# %%
vid.annotate('/tmp/out.mp4')
# Out:
# '/tmp/out.mp4'
