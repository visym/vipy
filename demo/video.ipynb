# %%
import vipy.video
from vipy.object import Track
from vipy.geometry import BoundingBox

# %%
bb = BoundingBox(xmin=280,ymin=850,width=600,height=300)
track1 = Track('Person', frames=[100], boxes=[bb])
print(track1)
# Out:
# <vipy.object.track: category="Person", frame=[100,100], keyframes=1>

# %%
mp4file = '../test/Video.mp4'
vid = vipy.video.Scene(filename=mp4file, tracks=[track1])
print(vid)
# Out:
# <vipy.video.scene: filename="../test/Video.mp4", tracks=1>

# %%
vid.load()
# Out:
# [vipy.video.load]: Loading "../test/Video.mp4"
# <vipy.video.scene: height=1920, width=1080, frames=321, filename="../test/Video.mp4", tracks=1>

# %%
vid.numpy().shape
# Out:
# (321, 1920, 1080, 3)

# %%
vid[100].rescale(0.25).show()
# Out:
# <vipy.image.scene: height=480, width=270, color='rgb', objects=1>

# %%
vid = vid.flush().clip(startframe=100,endframe=200).rot90ccw().mindim(256).load()
# Out:
# [vipy.video.load]: Loading "../test/Video.mp4"

# %%
vid[0].show()
# Out:
# <vipy.image.scene: height=256, width=455, color='rgb', objects=1>

# %%
vid.annotate('annotated_video.mp4')
# Out:
# 'annotated_video.mp4'
