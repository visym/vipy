# %%
from vipy.dataset.kinetics import Kinetics700
from vipy.dataset.activitynet import ActivityNet
from vipy.dataset.lfw import LFW
from vipy.video import VideoCategory

# %%
kinetics = Kinetics700('/tmp/kinetics').download(verbose=False)
print(kinetics)
# Out:
# Progress:                    1 files extracted [14.3% Progress:                    2 files extracted [28.6% Progress:                    3 files extracted [42.9% Progress:                    4 files extracted [57.1% Progress:                    5 files extracted [71.4% Progress:                    6 files extracted [85.7% Progress:                    7 files extracted [100.0
# <vipy.dataset.Kinetics700: "/tmp/kinetics/Kinetics700">

# %%
trainset = kinetics.trainset()

# %%
instance = trainset[0]
print(instance)
# Out:
# <vipy.video.VideoCategory: url="https://www.youtube.com/watch?v=---0dWlqevI", category="clay pottery making", clip=(570,870)>

# %%
print(trainset[1])
# Out:
# <vipy.video.VideoCategory: url="https://www.youtube.com/watch?v=---aQ-tA5_A", category="news anchoring", clip=(270,570)>

# %%
vid = instance.load()
print(vid)
print(vid.torch().shape)
print(vid[150])
print(vid[150].numpy().shape)
# Out:
# [vipy.videosearch.download]: saving "https://www.youtube.com/watch?v=---0dWlqevI" to "/tmp/kinetics/Kinetics700/---0dWlqevI"
# [vipy.video.load]: Loading "/tmp/kinetics/Kinetics700/---0dWlqevI.mp4"
# <vipy.video.VideoCategory: height=1440, width=810, frames=300, filename="/tmp/kinetics/Kinetics700/---0dWlqevI.mp4", url="https://www.youtube.com/watch?v=---0dWlqevI", category="clay pottery making">
# torch.Size([300, 3, 1440, 810])
# <vipy.image: height=1440, width=810, color='rgb'>
# (1440, 810, 3)

# %%
trainset[0][150].resize(width=512).show()
# Out:
# <vipy.image: height=910, width=512, color='rgb'>
