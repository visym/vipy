# %%
import vipy.video
from vipy.object import Track
from vipy.activity import Activity

# %%
v = vipy.video.Scene('../test/Video.mp4', startframe=30, endframe=90)

# %%
v.mindim(512).rot90ccw()
# Out:
# <vipy.video.scene: filename="../test/Video.mp4", fps=30.0>

# %%
v.thumbnail().show()
# Out:
# <vipy.image: height=512, width=910, color=rgba>
