# %%
from vipy.annotation import googlesearch
from vipy.image import ImageCategory, Batch
from vipy.visualize import montage

# %%
urls = googlesearch('owl')
imlist = [ImageCategory(url=url, category='owl').load(ignoreErrors=True) for url in urls]
# Out:
# /Users/jba3139/dev/vipy/vipy/image.py:129: UserWarning: [vipy.image][WARNING]: Load error for image "/Users/jba3139/.vipy/googlelogo_dark_color_188x64dp.png" - Ignoring
#   warnings.warn('[vipy.image][WARNING]: Load error for image "%s" - Ignoring' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:173: UserWarning: [vipy.image][WARNING]: download failed - Ignoring image
#   warnings.warn('[vipy.image][WARNING]: download failed - Ignoring image')
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/Baby-owl-by-Heather-Dobosz-730x330.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/Snowy-owl-Kenneth-Bishop.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/Northern%20Saw-whet%20Owl.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:180: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/800x1200-barn-owl-classroom.jpg" - Ignoring image
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring image' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:129: UserWarning: [vipy.image][WARNING]: Load error for image "/Users/jba3139/.vipy/800x1200-barn-owl-classroom.jpg" - Ignoring
#   warnings.warn('[vipy.image][WARNING]: Load error for image "%s" - Ignoring' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/e28749695d5ed2b25b157b10e577cf84.png" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/virtualenv/diva/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:780: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/owl.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/barred-owl-5a317a0ee258f80036aa6d8c.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/short-eared-owl-5c17f5a546e0fb00012c3e3b.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/barred-owl-in-snag-at-BLK_T-Peck.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/Barn-Owl-Ears_660x550-660x550.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/schlitz-audubon-owls.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/636502486222667262-Snowy-owl-14.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/2-615x290.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/tskili-great-horned-owl-schlitz-audubon.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())
# /Users/jba3139/dev/vipy/vipy/image.py:119: UserWarning: [vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "/Users/jba3139/.vipy/Barn-Owl_Sherman-Wing-1024x1024.jpg" - Ignoring.
#   warnings.warn('[vipy.image][WARNING]: IO error - Invalid image file, url or invalid write permissions "%s" - Ignoring. ' % self.filename())

# %%
imbatch = Batch([im for im in imlist if im.isloaded()])
imlist = imbatch.mindim(224).centersquare().rgb().list() 
print(imbatch.torch().shape)
# Out:
# torch.Size([71, 3, 224, 224])

# %%
help(montage)
montage(imlist, 128, 128, do_plot=True);
# Out:
# Help on function montage in module vipy.visualize:
#
# montage(imset, gridrows, gridcols, imgrows=None, imgcols=None, aspectratio=1, crop=False, skip=True, do_plot=False, figure=None, border=0, border_bgr=(128, 128, 128), do_flush=False, verbose=False)
#     Montage image of images of grid size (gridrows,gridcols), such that montage has given aspect ratio  or is exactly (rows x cols).  Pass in iterable of imagedetection objects which is used to montage rowwise
