# %%
from vipy.image import ImageDetection

# %%
url='https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg'
im = ImageDetection(url=url, category='Great Horned Owl').boundingbox(xmin=240, ymin=320, width=1400, height=2100)

# %%
im.rescale(0.25).show()
# Out:
# <vipy.imagedetection: height=600, width=480, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=60.0,ymin=80.0,xmax=410.0,ymax=599.0)>

# %%
help(im.minsquare)
im.minsquare().show()
# Out:
# Help on method minsquare in module vipy.image:
#
# minsquare() method of vipy.image.ImageDetection instance
#     Crop image of size (HxW) to (min(H,W), min(H,W))
# <vipy.imagedetection: height=480, width=480, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=60.0,ymin=80.0,xmax=410.0,ymax=479.0)>

# %%
help(im.dilate)
im.dilate(0.75).show()
# Out:
# Help on method dilate in module vipy.image:
#
# dilate(s) method of vipy.image.ImageDetection instance
#     Dilate bounding box by scale factor
# <vipy.imagedetection: height=480, width=480, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=103.8,ymin=129.9,xmax=366.2,ymax=429.1)>

# %%
help(im.maxside)
im.maxside(256).crop().show()
# Out:
# Help on method maxside in module vipy.image:
#
# maxside(dim) method of vipy.image.ImageDetection instance
#     Resize image preserving aspect ratio so that maximum dimension of bounding box = dim
# <vipy.imagedetection: height=256, width=225, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=0.0,ymin=0.0,xmax=225.0,ymax=256.0)>

# %%
help(im.zeropad)
im.zeropad(64,64).show()
# Out:
# Help on method zeropad in module vipy.image:
#
# zeropad(dx, dy) method of vipy.image.ImageDetection instance
#     Pad image using np.pad constant
# <vipy.imagedetection: height=384, width=353, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=64.0,ymin=64.0,xmax=289.0,ymax=320.0)>
