# %%
from vipy.image import ImageDetection

# %%
url='https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg'
im = ImageDetection(url=url, category='Great Horned Owl').boundingbox(xmin=300, ymin=320, width=1200, height=1600)

# %%
im.resize(cols=512).show()
# Out:
# <vipy.imagedetection: height=640, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=80.0,ymin=85.3,xmax=400.0,ymax=512.0)>

# %%
help(im.maxsquare)
im.maxsquare().show()
# Out:
# Help on method maxsquare in module vipy.image:
#
# maxsquare() method of vipy.image.ImageDetection instance
#     Set a square bounding box centered at current centroid, such that the box dim=max(bbwidth, bbheight), do not crop the image
# <vipy.imagedetection: height=640, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=26.7,ymin=85.3,xmax=453.3,ymax=512.0)>

# %%
help(im.dilate)
im.dilate(0.75).show()
# Out:
# Help on method dilate in module vipy.image:
#
# dilate(s) method of vipy.image.ImageDetection instance
#     Dilate bounding box by scale factor
# <vipy.imagedetection: height=640, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=80.0,ymin=138.7,xmax=400.0,ymax=458.7)>

# %%
help(im.maxside)
im.maxside(256).crop().show()
# Out:
# Help on method maxside in module vipy.image:
#
# maxside(dim) method of vipy.image.ImageDetection instance
#     Resize image preserving aspect ratio so that maximum dimension of bounding box = dim
# <vipy.imagedetection: height=256, width=257, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=0.0,ymin=0.0,xmax=257.0,ymax=256.0)>

# %%
help(im.zeropad)
im.zeropad(64,64).show()
# Out:
# Help on method zeropad in module vipy.image:
#
# zeropad(dx, dy) method of vipy.image.ImageDetection instance
#     Pad image with dx=(leftpadwidth,rightpadwidth) or dx=bothpadwidth to zeropad left and right, dy=(toppadheight,bottompadheight) or dy=bothpadheight to zeropad top and bottom
# <vipy.imagedetection: height=384, width=385, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=64.0,ymin=64.0,xmax=321.0,ymax=320.0)>
