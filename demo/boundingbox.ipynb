# %%
from vipy.image import ImageDetection
from vipy.image import Scene
from vipy.object import Detection

# %%
url='https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg'
im = ImageDetection(url=url, category='Great Horned Owl').boundingbox(xmin=300, ymin=320, width=1200, height=1600)

# %%
help(im.resize)
im.resize(cols=512).show()
# Out:
# Help on method resize in module vipy.image:
#
# resize(cols=None, rows=None) method of vipy.image.ImageDetection instance
#     Resize image buffer and bounding box so that the image buffer is size (height=cols, width=row).  If only cols or rows is provided, then scale the image appropriately
# <vipy.imagedetection: height=640, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=80.0, ymin=85.3, width=320.0, height=426.7)>

# %%
help(im.centersquare)
im.centersquare().show()
# Out:
# Help on method centersquare in module vipy.image:
#
# centersquare() method of vipy.image.ImageDetection instance
#     Crop image of size (NxN) in the center, such that N=min(width,height), keeping the image centroid constant, new bounding box may be degenerate
# <vipy.imagedetection: height=512, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=80.0, ymin=21.3, width=320.0, height=426.7)>

# %%
help(im.dilate)
im.dilate(0.75).show()
# Out:
# Help on method dilate in module vipy.image:
#
# dilate(s) method of vipy.image.ImageDetection instance
#     Dilate bounding box by scale factor
# <vipy.imagedetection: height=512, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=120.0, ymin=74.7, width=240.0, height=320.0)>

# %%
help(im.crop)
help(im.maxdim)
im.crop().maxdim(256).show()
# Out:
# Help on method crop in module vipy.image:
#
# crop() method of vipy.image.ImageDetection instance
#     Crop image using stored bounding box, then set the bounding box equal to the new image rectangle
#
# Help on method maxdim in module vipy.image:
#
# maxdim(dim) method of vipy.image.ImageDetection instance
#     Resize image preserving aspect ratio so that maximum dimension of image = dim
# <vipy.imagedetection: height=256, width=192, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=0.0, ymin=0.0, width=192.0, height=256.0)>

# %%
help(im.zeropad)
im.zeropad(64,64).show()
# Out:
# Help on method zeropad in module vipy.image:
#
# zeropad(dx, dy) method of vipy.image.ImageDetection instance
#     Pad image with dx=(leftpadwidth,rightpadwidth) or dx=bothpadwidth to zeropad left and right, dy=(toppadheight,bottompadheight) or dy=bothpadheight to zeropad top and bottom
# <vipy.imagedetection: height=384, width=320, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url="https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg", category="Great Horned Owl", bbox=(xmin=64.0, ymin=64.0, width=192.0, height=256.0)>

# %%
im = Scene(url=url, category='Great Horned Owl', objects=[Detection('left eye', xmin=600, ymin=800, width=250, height=250), 
                                                          Detection('right eye', xmin=1000, ymin=800, width=250, height=250)])
print(im)
print(im.objects())
# Out:
# <vipy.image.scene: url=https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg, category=Great Horned Owl, objects=2>
# [<vipy.object.detection: category="left eye", bbox=(xmin=600.0, ymin=800.0, width=250.0, height=250.0)>, <vipy.object.detection: category="right eye", bbox=(xmin=1000.0, ymin=800.0, width=250.0, height=250.0)>]

# %%
im.mindim(512).show()
# Out:
# <vipy.image.scene: height=640, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url=https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg, category=Great Horned Owl, objects=2>

# %%
help(im.fliplr)
im.fliplr().show()
# Out:
# Help on method fliplr in module vipy.image:
#
# fliplr() method of vipy.image.Scene instance
#     Mirror buffer and all bounding box around vertical axis
# <vipy.image.scene: height=640, width=512, color='rgb', filename="/Users/jba3139/.vipy/1920px-Bubo_virginianus_06.jpg", url=https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Bubo_virginianus_06.jpg/1920px-Bubo_virginianus_06.jpg, category=Great Horned Owl, objects=2>
